# %% [markdown]
# # Virtual Lesion

# %% [markdown]
# This series of Notebooks (Step 3 to 3) calculate the likeliness of the existens of a fiber bundle with LiFEs Virtual Lesion approach. The probability will be difined based on the Strength of Evidence.

# %%
import os
import numpy as np
from nibabel import trackvis as tv
from utilities import *
import nibabel as nib
from dipy.tracking import utils

# %%
plot = False

# %%
if plot == True:
    import matplotlib.pyplot as plt
    # %matplotlib inline

# %%
path_saveing = '/data/hcp/data/'
path = '/hcp/'

# %%
subjects = os.listdir(path_saveing)
subjects_sorted = sorted(subjects)
subjects_sorted.remove('.nii.gz')

for subject in subjects_sorted:
    print 'Process subject ' + subject

    if os.path.isfile(os.path.join(path_saveing, subject, 'RVLPFC2FIRSTamyg_bigRight_Strength_of_Evidence3.txt')) == False:
        print "    Strength of Evidence does not exist, start calculation"
        
        if os.path.isfile(os.path.join(path_saveing, subject, 'RVLPFC2FIRSTamyg_bigRight_neighborhood.nii.gz')) == True and os.path.isfile(os.path.join(path_saveing, subject, 'RVLPFC2FIRSTamyg_bigRight_LiFE_rmse_with_path.nii.gz')) == True and os.path.isfile(os.path.join(path_saveing, subject, 'RVLPFC2FIRSTamyg_bigRight_LiFE_rmse_without_path.nii.gz')) == True and os.path.isfile(os.path.join(path, subject, 'T1w/Diffusion/data.nii.gz')) == True:
            print "    All necessary files exist, continue"
            
            directory_output = os.path.join(path_saveing, subject)

            #mask = load_nifti(path_saveing + subject + "/RVLPFC2FIRSTamyg_bigRight_neighborhood")
            #mask = mask.astype(bool)

            #with_path = load_nifti(path_saveing + subject + "/RVLPFC2FIRSTamyg_bigRight_LiFE_rmse_with_path")
            #without_path = load_nifti(path_saveing + subject + "/RVLPFC2FIRSTamyg_bigRight_LiFE_rmse_without_path")

            #data, affine, gtab, header, shell_mask = load_hcp_data(path, subject)

            #noise = data[..., gtab.b0s_mask].std(axis=3, ddof=1) 

            #print "    Total Error divided by STD before adding: %.2f" % np.sum(without_path[mask]/noise[mask])
            #print "    Total Error divided by STD after adding : %.2f" % np.sum(with_path[mask]/noise[mask])
            #strength = np.sum(without_path[mask]/noise[mask]) - np.sum(with_path[mask]/noise[mask])
            #print "    Strength of Evidence                    : %.2f" % strength

            #np.savetxt(os.path.join(path_saveing, subject, 'RVLPFC2FIRSTamyg_bigRight_Strength_of_Evidence2.txt'), np.array([strength]), delimiter=',')

            
            print "    Calculate optimized Fibers"
            beta_with = load_matlab_file(path_saveing + subject + "/RVLPFC2FIRSTamyg_bigRight_LiFE_betas_with_path")['beta']

            streams, hdr = tv.read(path_saveing + subject + "/RVLPFC2FIRSTamyg_bigRight_clustered.trk")#, points_space='voxel'
            streamlines = [i[0] for i in streams]

            weights_with = np.squeeze(beta_with[:, -len(streamlines):])
            optimized_with = streamlines[-len(streamlines):]
            
            try:
                optimized_sl = list(np.array(optimized_with)[np.where(weights_with > 0)])

                optimized_save = ((sl, None, None) for sl in optimized_sl)
                tv.write(os.path.join(path_saveing, subject, 'RVLPFC2FIRSTamyg_bigRight_optimized.trk'), optimized_save,  hdr_mapping=hdr)
            except:
                print "Could not save streamlines, 0 streamlines detected"
        
            """
            beta_without = load_matlab_file(path_saveing + subject + "/RVLPFC2FIRSTamyg_bigRight_LiFE_betas_without_path")['beta']

            streams_neighbourhood, hdr_neighbourhood = tv.read(path_saveing + subject + "/RVLPFC2FIRSTamyg_bigRight_2M_SIFT_with_path.trk", points_space='voxel')
            streamlines_neighbourhood = [i[0] for i in streams_neighbourhood]

            bins_RMSE = np.linspace(50.0,500,100)
            hist_with = np.histogram(with_path[mask], bins=bins_RMSE)
            hist_without = np.histogram(without_path[mask], bins=bins_RMSE)

            if plot == True:
                red = plt.plot(bins_RMSE[:-1], hist_with[0]*1.0/np.sum(mask), 'r')
                blue = plt.plot(bins_RMSE[:-1], hist_without[0]*1.0/np.sum(mask), 'b')
                plt.xlabel('RMSE of Diffusion Weighted Signal only')
                plt.ylabel('Probability')
                plt.legend((red[0], blue[0]), ('With Path', 'Without Path'))
                plt.title('Histogram of RMSE')

            weights_with = np.squeeze(beta_with[:, -len(streamlines):])

            mask_beta = beta_with != 0
            non_zero_beta = beta_with[mask_beta]

            mask_beta_artifically = weights_with != 0
            non_zero_beta_artifically = weights_with[mask_beta_artifically]

            if plot == True:
                bins_beta = np.linspace(0.0,0.007,100)
                hist_beta = np.histogram(non_zero_beta, bins=bins_beta)
                percentage = hist_beta[0]*1.0/non_zero_beta.shape[0]
                bins_plot = bins_beta[:-1]
                red = plt.plot(bins_plot, percentage, 'r')

                for value in non_zero_beta_artifically:
                    idx = (np.abs(bins_plot - value)).argmin()
                    blue = plt.plot(bins_plot[idx], percentage[idx], 'bo')

                plt.legend((red[0], blue[0]), ('Hole Neighborhood', 'Artificially added Fibers'))
                plt.title('Histogram of Betas with Path')
                plt.xlabel('Beta per Fiber calculated by LiFE')
                plt.ylabel('Probability')

            density = utils.density_map(streamlines, hdr['dim'], [1, 1, 1])

            mask_density = density != 0
            non_zero_density = density[mask_density]

            density_neighbourhood = utils.density_map(streamlines_neighbourhood, hdr_neighbourhood['dim'], [1, 1, 1])

            mask_density_neighbourhood = density_neighbourhood != 0
            non_zero_density_neighbourhood = density_neighbourhood[mask_density_neighbourhood]

            bins_density = np.linspace(0.0,30,100)
            hist_denisty = np.histogram(non_zero_density, bins=bins_density)
            hist_denisty_neighbourhood = np.histogram(non_zero_density_neighbourhood, bins=bins_density)

            if plot == True:
                red = plt.plot(bins_density[:-1], hist_denisty_neighbourhood[0]*1.0/np.max(hist_denisty_neighbourhood[0]), 'r')
                blue = plt.plot(bins_density[:-1], hist_denisty[0]*1.0/np.max(hist_denisty[0]), 'b')
                plt.legend((red[0], blue[0]), ('Neighborhood', 'Artificially added Fibers'))
                plt.xlabel('Fiber Density per Voxel')
                plt.ylabel('Relative Quantity')
                plt.title('Histogram of Fiber Density')
            """
        else:
            print "    Not all necessary files exist, skip subject"
            
    else:
        print "Strength of Evidence Exists already, skip subject"
# Out:
# Process subject 100307
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 100408
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 101006
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 101107
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 101309
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 101410
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 101915
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 102008
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 102311
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 102816
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 103111
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 103414
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 103515
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 103818
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 104820
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 105014
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 105115
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 105216
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 106016
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 106319
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 106521
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 107321
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 107422
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 108121
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 108323
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 108525
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 108828
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 109123
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 110411
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 111312
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 111413
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 111716
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 112819
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 113215
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 113619
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 113821
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 113922
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 114419
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 115320
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 116524
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 117122
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 117324
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 118528
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 118730
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 118932
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 119833
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 120111
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 120212
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 120515
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 121618
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 122317
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 122620
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 123117
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 123420
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 123925
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 124220
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 124422
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 124826
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 125525
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 126325
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 126628
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 127630
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 127933
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 128127
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 128632
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 129028
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 130013
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 130316
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 130922
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 131217
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 131722
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 131924
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 132118
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 133019
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 133625
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 133827
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 133928
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 134324
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 135225
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 135528
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 135932
#     Strength of Evidence does not exist, start calculation
#     Not all necessary files exist, skip subject
# Process subject 136227
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 136833
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 137027
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 137128
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 137633
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 137936
#     Strength of Evidence does not exist, start calculation
#     Not all necessary files exist, skip subject
# Process subject 138231
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 138534
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 139233
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 139637
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 140117
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 140420
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 140824
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 140925
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 141422
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 141826
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 142626
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 142828
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 143325
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 144226
#     Strength of Evidence does not exist, start calculation
#     Not all necessary files exist, skip subject
# Process subject 144832
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 145834
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 146331
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 146432
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 147030
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 147737
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 148032
#     Strength of Evidence does not exist, start calculation
#     Not all necessary files exist, skip subject
# Process subject 148335
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 148840
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 148941
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 149337
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 149539
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 149741
#     Strength of Evidence does not exist, start calculation
#     Not all necessary files exist, skip subject
# Process subject 150423
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 150524
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 150625
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 150726
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 151223
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 151526
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 151627
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 151728
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 152831
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 153025
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 153429
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 153833
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 154431
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 154734
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 154835
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 154936
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 155231
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 155635
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 156637
#     Strength of Evidence does not exist, start calculation
#     Not all necessary files exist, skip subject
# Process subject 157336
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 157437
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 158035
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 158136
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 158540
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 159138
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 159239
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 159340
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 159441
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 160123
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 160830
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 161327
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 161630
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 161731
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 162026
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 162228
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 162329
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 162733
#     Strength of Evidence does not exist, start calculation
#     Not all necessary files exist, skip subject
# Process subject 163129
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 163331
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 163432
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 163836
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 164030
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 164131
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 164939
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 165032
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 165840
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 166438
#     Strength of Evidence does not exist, start calculation
#     Not all necessary files exist, skip subject
# Process subject 167036
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 167743
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 168139
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Could not save streamlines, 0 streamlines detected
# Process subject 168341
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 169343
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 169444
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 170934
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 171431
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 171633
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 172029
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 172130
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 172332
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 172534
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 172938
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 173132
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 173334
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 173435
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 173536
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 173940
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 175035
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 175439
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 176542
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 177645
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 177746
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 178142
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 178748
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 178950
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 179346
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 179548
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 180129
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 180432
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 180836
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 180937
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 181131
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 181232
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 182739
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 182840
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 183034
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 185442
#     Strength of Evidence does not exist, start calculation
#     Not all necessary files exist, skip subject
# Process subject 186141
#     Strength of Evidence does not exist, start calculation
#     Not all necessary files exist, skip subject
# Process subject 187143
#     Strength of Evidence does not exist, start calculation
#     Not all necessary files exist, skip subject
# Process subject 187547
#     Strength of Evidence does not exist, start calculation
#     Not all necessary files exist, skip subject
# Process subject 187850
#     Strength of Evidence does not exist, start calculation
#     Not all necessary files exist, skip subject
# Process subject 189349
#     Strength of Evidence does not exist, start calculation
#     Not all necessary files exist, skip subject
# Process subject 190031
#     Strength of Evidence does not exist, start calculation
#     Not all necessary files exist, skip subject
# Process subject 191033
#     Strength of Evidence does not exist, start calculation
#     Not all necessary files exist, skip subject
# Process subject 191336
#     Strength of Evidence does not exist, start calculation
#     Not all necessary files exist, skip subject
# Process subject 191437
#     Strength of Evidence does not exist, start calculation
#     Not all necessary files exist, skip subject
# Process subject 191841
#     Strength of Evidence does not exist, start calculation
#     Not all necessary files exist, skip subject
# Process subject 192439
#     Strength of Evidence does not exist, start calculation
#     Not all necessary files exist, skip subject
# Process subject 192540
#     Strength of Evidence does not exist, start calculation
#     Not all necessary files exist, skip subject
# Process subject 192843
#     Strength of Evidence does not exist, start calculation
#     Not all necessary files exist, skip subject
# Process subject 193239
#     Strength of Evidence does not exist, start calculation
#     Not all necessary files exist, skip subject
# Process subject 194140
#     Strength of Evidence does not exist, start calculation
#     Not all necessary files exist, skip subject
# Process subject 194645
#     Strength of Evidence does not exist, start calculation
#     Not all necessary files exist, skip subject
# Process subject 194847
#     Strength of Evidence does not exist, start calculation
#     Not all necessary files exist, skip subject
# Process subject 195041
#     Strength of Evidence does not exist, start calculation
#     Not all necessary files exist, skip subject
# Process subject 195647
#     Strength of Evidence does not exist, start calculation
#     Not all necessary files exist, skip subject
# Process subject 195849
#     Strength of Evidence does not exist, start calculation
#     Not all necessary files exist, skip subject
# Process subject 196144
#     Strength of Evidence does not exist, start calculation
#     Not all necessary files exist, skip subject
# Process subject 196750
#     Strength of Evidence does not exist, start calculation
#     Not all necessary files exist, skip subject
# Process subject 197348
#     Strength of Evidence does not exist, start calculation
#     Not all necessary files exist, skip subject
# Process subject 197550
#     Strength of Evidence does not exist, start calculation
#     Not all necessary files exist, skip subject
# Process subject 197651
#     Strength of Evidence does not exist, start calculation
#     Not all necessary files exist, skip subject
# Process subject 198350
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 198451
#     Strength of Evidence does not exist, start calculation
#     Not all necessary files exist, skip subject
# Process subject 198855
#     Strength of Evidence does not exist, start calculation
#     Not all necessary files exist, skip subject
# Process subject 199150
#     Strength of Evidence does not exist, start calculation
#     Not all necessary files exist, skip subject
# Process subject 199251
#     Strength of Evidence does not exist, start calculation
#     Not all necessary files exist, skip subject
# Process subject 199453
#     Strength of Evidence does not exist, start calculation
#     Not all necessary files exist, skip subject
# Process subject 199655
#     Strength of Evidence does not exist, start calculation
#     Not all necessary files exist, skip subject
# Process subject 199958
#     Strength of Evidence does not exist, start calculation
#     Not all necessary files exist, skip subject
# Process subject 200109
#     Strength of Evidence does not exist, start calculation
#     Not all necessary files exist, skip subject
# Process subject 200614
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 201414
#     Strength of Evidence does not exist, start calculation
#     Not all necessary files exist, skip subject
# Process subject 201818
#     Strength of Evidence does not exist, start calculation
#     Not all necessary files exist, skip subject
# Process subject 203418
#     Strength of Evidence does not exist, start calculation
#     Not all necessary files exist, skip subject
# Process subject 204016
#     Strength of Evidence does not exist, start calculation
#     Not all necessary files exist, skip subject
# Process subject 204521
#     Strength of Evidence does not exist, start calculation
#     Not all necessary files exist, skip subject
# Process subject 205119
#     Strength of Evidence does not exist, start calculation
#     Not all necessary files exist, skip subject
# Process subject 205220
#     Strength of Evidence does not exist, start calculation
#     Not all necessary files exist, skip subject
# Process subject 205725
#     Strength of Evidence does not exist, start calculation
#     Not all necessary files exist, skip subject
# Process subject 205826
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 208024
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 208226
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 208428
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 209935
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 210011
#     Strength of Evidence does not exist, start calculation
#     Not all necessary files exist, skip subject
# Process subject 210415
#     Strength of Evidence does not exist, start calculation
#     Not all necessary files exist, skip subject
# Process subject 210617
#     Strength of Evidence does not exist, start calculation
#     Not all necessary files exist, skip subject
# Process subject 211215
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 211316
#     Strength of Evidence does not exist, start calculation
#     Not all necessary files exist, skip subject
# Process subject 211417
#     Strength of Evidence does not exist, start calculation
#     Not all necessary files exist, skip subject
# Process subject 211720
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 211922
#     Strength of Evidence does not exist, start calculation
#     Not all necessary files exist, skip subject
# Process subject 212116
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 212217
#     Strength of Evidence does not exist, start calculation
#     Not all necessary files exist, skip subject
# Process subject 212318
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 212419
#     Strength of Evidence does not exist, start calculation
#     Not all necessary files exist, skip subject
# Process subject 214019
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 214221
#     Strength of Evidence does not exist, start calculation
#     Not all necessary files exist, skip subject
# Process subject 214726
#     Strength of Evidence does not exist, start calculation
#     Not all necessary files exist, skip subject
# Process subject 217126
#     Strength of Evidence does not exist, start calculation
#     Not all necessary files exist, skip subject
# Process subject 217429
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 221319
#     Strength of Evidence does not exist, start calculation
#     Not all necessary files exist, skip subject
# Process subject 224022
#     Strength of Evidence does not exist, start calculation
#     Not all necessary files exist, skip subject
# Process subject 231928
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 233326
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 239944
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 245333
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 246133
#     Strength of Evidence does not exist, start calculation
#     Not all necessary files exist, skip subject
# Process subject 249947
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 250427
#     Strength of Evidence does not exist, start calculation
#     Not all necessary files exist, skip subject
# Process subject 250932
#     Strength of Evidence does not exist, start calculation
#     Not all necessary files exist, skip subject
# Process subject 251833
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 255639
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 268850
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 284646
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 285345
#     Strength of Evidence does not exist, start calculation
#     Not all necessary files exist, skip subject
# Process subject 285446
#     Strength of Evidence does not exist, start calculation
#     Not all necessary files exist, skip subject
# Process subject 289555
#     Strength of Evidence does not exist, start calculation
#     Not all necessary files exist, skip subject
# Process subject 290136
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 293748
#     Strength of Evidence does not exist, start calculation
#     Not all necessary files exist, skip subject
# Process subject 298051
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 298455
#     Strength of Evidence does not exist, start calculation
#     Not all necessary files exist, skip subject
# Process subject 303119
#     Strength of Evidence does not exist, start calculation
#     Not all necessary files exist, skip subject
# Process subject 303624
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 304020
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 307127
#     Strength of Evidence does not exist, start calculation
#     Not all necessary files exist, skip subject
# Process subject 316633
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 329440
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 334635
#     Strength of Evidence does not exist, start calculation
#     Not all necessary files exist, skip subject
# Process subject 339847
#     Strength of Evidence does not exist, start calculation
#     Not all necessary files exist, skip subject
# Process subject 351938
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 352132
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 352738
#     Strength of Evidence does not exist, start calculation
#     Not all necessary files exist, skip subject
# Process subject 355239
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 356948
#     Strength of Evidence does not exist, start calculation
#     Not all necessary files exist, skip subject
# Process subject 365343
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 366042
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 366446
#     Strength of Evidence does not exist, start calculation
#     Not all necessary files exist, skip subject
# Process subject 371843
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 377451
#     Strength of Evidence does not exist, start calculation
#     Not all necessary files exist, skip subject
# Process subject 380036
#     Strength of Evidence does not exist, start calculation
#     Not all necessary files exist, skip subject
# Process subject 382242
#     Strength of Evidence does not exist, start calculation
#     Not all necessary files exist, skip subject
# Process subject 385450
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 386250
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 390645
#     Strength of Evidence does not exist, start calculation
#     Not all necessary files exist, skip subject
# Process subject 395958
#     Strength of Evidence does not exist, start calculation
#     Not all necessary files exist, skip subject
# Process subject 397154
#     Strength of Evidence does not exist, start calculation
#     Not all necessary files exist, skip subject
# Process subject 397760
#     Strength of Evidence does not exist, start calculation
#     Not all necessary files exist, skip subject
# Process subject 397861
#     Strength of Evidence does not exist, start calculation
#     Not all necessary files exist, skip subject
# Process subject 412528
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 414229
#     Strength of Evidence does not exist, start calculation
#     Not all necessary files exist, skip subject
# Process subject 415837
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 422632
#     Strength of Evidence does not exist, start calculation
#     Not all necessary files exist, skip subject
# Process subject 433839
#     Strength of Evidence does not exist, start calculation
#     Not all necessary files exist, skip subject
# Process subject 436239
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 436845
#     Strength of Evidence does not exist, start calculation
#     Not all necessary files exist, skip subject
# Process subject 441939
#     Strength of Evidence does not exist, start calculation
#     Not all necessary files exist, skip subject
# Process subject 445543
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 448347
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 465852
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 473952
#     Strength of Evidence does not exist, start calculation
#     Not all necessary files exist, skip subject
# Process subject 475855
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 479762
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 480141
# ...
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 580347
#     Strength of Evidence does not exist, start calculation
#     Not all necessary files exist, skip subject
# Process subject 581349
#     Strength of Evidence does not exist, start calculation
#     Not all necessary files exist, skip subject
# Process subject 585862
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 586460
#     Strength of Evidence does not exist, start calculation
#     Not all necessary files exist, skip subject
# Process subject 592455
#     Strength of Evidence does not exist, start calculation
#     Not all necessary files exist, skip subject
# Process subject 594156
#     Strength of Evidence does not exist, start calculation
#     Not all necessary files exist, skip subject
# Process subject 598568
#     Strength of Evidence does not exist, start calculation
#     Not all necessary files exist, skip subject
# Process subject 599469
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 599671
#     Strength of Evidence does not exist, start calculation
#     Not all necessary files exist, skip subject
# Process subject 601127
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 613538
#     Strength of Evidence does not exist, start calculation
#     Not all necessary files exist, skip subject
# Process subject 620434
#     Strength of Evidence does not exist, start calculation
#     Not all necessary files exist, skip subject
# Process subject 622236
#     Strength of Evidence does not exist, start calculation
#     Not all necessary files exist, skip subject
# Process subject 623844
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 627549
#     Strength of Evidence does not exist, start calculation
#     Not all necessary files exist, skip subject
# Process subject 638049
#     Strength of Evidence does not exist, start calculation
#     Not all necessary files exist, skip subject
# Process subject 644044
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 645551
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 654754
#     Strength of Evidence does not exist, start calculation
#     Not all necessary files exist, skip subject
# Process subject 665254
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 672756
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 673455
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 677968
#     Strength of Evidence does not exist, start calculation
#     Not all necessary files exist, skip subject
# Process subject 679568
#     Strength of Evidence does not exist, start calculation
#     Not all necessary files exist, skip subject
# Process subject 680957
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 683256
#     Strength of Evidence does not exist, start calculation
#     Not all necessary files exist, skip subject
# Process subject 685058
#     Strength of Evidence does not exist, start calculation
#     Not all necessary files exist, skip subject
# Process subject 687163
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 690152
#     Strength of Evidence does not exist, start calculation
#     Not all necessary files exist, skip subject
# Process subject 695768
#     Strength of Evidence does not exist, start calculation
#     Not all necessary files exist, skip subject
# Process subject 704238
#     Strength of Evidence does not exist, start calculation
#     Not all necessary files exist, skip subject
# Process subject 705341
#     Strength of Evidence does not exist, start calculation
#     Not all necessary files exist, skip subject
# Process subject 709551
#     Strength of Evidence does not exist, start calculation
#     Not all necessary files exist, skip subject
# Process subject 713239
#     Strength of Evidence does not exist, start calculation
#     Not all necessary files exist, skip subject
# Process subject 715041
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 715647
#     Strength of Evidence does not exist, start calculation
#     Not all necessary files exist, skip subject
# Process subject 729254
#     Strength of Evidence does not exist, start calculation
#     Not all necessary files exist, skip subject
# Process subject 729557
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 732243
#     Strength of Evidence does not exist, start calculation
#     Not all necessary files exist, skip subject
# Process subject 734045
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 742549
#     Strength of Evidence does not exist, start calculation
#     Not all necessary files exist, skip subject
# Process subject 748258
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 748662
#     Strength of Evidence does not exist, start calculation
#     Not all necessary files exist, skip subject
# Process subject 749361
#     Strength of Evidence does not exist, start calculation
#     Not all necessary files exist, skip subject
# Process subject 751348
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 753251
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 756055
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 759869
#     Strength of Evidence does not exist, start calculation
#     Not all necessary files exist, skip subject
# Process subject 761957
#     Strength of Evidence does not exist, start calculation
#     Not all necessary files exist, skip subject
# Process subject 765056
#     Strength of Evidence does not exist, start calculation
#     Not all necessary files exist, skip subject
# Process subject 770352
#     Strength of Evidence does not exist, start calculation
#     Not all necessary files exist, skip subject
# Process subject 771354
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 779370
#     Strength of Evidence does not exist, start calculation
#     Not all necessary files exist, skip subject
# Process subject 782561
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 784565
#     Strength of Evidence does not exist, start calculation
#     Not all necessary files exist, skip subject
# Process subject 786569
#     Strength of Evidence does not exist, start calculation
#     Not all necessary files exist, skip subject
# Process subject 788876
#     Strength of Evidence does not exist, start calculation
#     Not all necessary files exist, skip subject
# Process subject 789373
#     Strength of Evidence does not exist, start calculation
#     Not all necessary files exist, skip subject
# Process subject 792564
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 792766
#     Strength of Evidence does not exist, start calculation
#     Not all necessary files exist, skip subject
# Process subject 802844
#     Strength of Evidence does not exist, start calculation
#     Not all necessary files exist, skip subject
# Process subject 814649
#     Strength of Evidence does not exist, start calculation
#     Not all necessary files exist, skip subject
# Process subject 816653
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 826353
#     Strength of Evidence does not exist, start calculation
#     Not all necessary files exist, skip subject
# Process subject 826454
#     Strength of Evidence does not exist, start calculation
#     Not all necessary files exist, skip subject
# Process subject 833148
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 833249
#     Strength of Evidence does not exist, start calculation
#     Not all necessary files exist, skip subject
# Process subject 837560
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 837964
#     Strength of Evidence does not exist, start calculation
#     Not all necessary files exist, skip subject
# Process subject 845458
#     Strength of Evidence does not exist, start calculation
#     Not all necessary files exist, skip subject
# Process subject 849971
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 856766
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 857263
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 859671
#     Strength of Evidence does not exist, start calculation
#     Not all necessary files exist, skip subject
# Process subject 861456
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 865363
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 871762
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 871964
#     Strength of Evidence does not exist, start calculation
#     Not all necessary files exist, skip subject
# Process subject 872158
#     Strength of Evidence does not exist, start calculation
#     Not all necessary files exist, skip subject
# Process subject 872764
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 877168
#     Strength of Evidence does not exist, start calculation
#     Not all necessary files exist, skip subject
# Process subject 877269
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 885975
#     Strength of Evidence does not exist, start calculation
#     Not all necessary files exist, skip subject
# Process subject 887373
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 889579
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 894673
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 896778
#     Strength of Evidence does not exist, start calculation
#     Not all necessary files exist, skip subject
# Process subject 896879
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 898176
#     Strength of Evidence does not exist, start calculation
#     Not all necessary files exist, skip subject
# Process subject 899885
#     Strength of Evidence does not exist, start calculation
#     Not all necessary files exist, skip subject
# Process subject 901038
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 901139
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 901442
#     Strength of Evidence does not exist, start calculation
#     Not all necessary files exist, skip subject
# Process subject 904044
#     Strength of Evidence does not exist, start calculation
#     Not all necessary files exist, skip subject
# Process subject 907656
#     Strength of Evidence does not exist, start calculation
#     Not all necessary files exist, skip subject
# Process subject 910241
#     Strength of Evidence does not exist, start calculation
#     Not all necessary files exist, skip subject
# Process subject 912447
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 917255
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 922854
#     Strength of Evidence does not exist, start calculation
#     Not all necessary files exist, skip subject
# Process subject 930449
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 932554
#     Strength of Evidence does not exist, start calculation
#     Not all necessary files exist, skip subject
# Process subject 957974
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 958976
#     Strength of Evidence does not exist, start calculation
#     Not all necessary files exist, skip subject
# Process subject 959574
#     Strength of Evidence does not exist, start calculation
#     Not all necessary files exist, skip subject
# Process subject 965367
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 965771
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 978578
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 979984
#     Strength of Evidence does not exist, start calculation
#     Not all necessary files exist, skip subject
# Process subject 983773
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 984472
#     Strength of Evidence does not exist, start calculation
#     Not all necessary files exist, skip subject
# Process subject 987983
#     Strength of Evidence does not exist, start calculation
#     Not all necessary files exist, skip subject
# Process subject 991267
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
# Process subject 992774
#     Strength of Evidence does not exist, start calculation
#     Not all necessary files exist, skip subject
# Process subject 994273
#     Strength of Evidence does not exist, start calculation
#     All necessary files exist, continue
#     Calculate optimized Fibers
